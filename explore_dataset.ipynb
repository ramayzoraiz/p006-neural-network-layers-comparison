# %%
import datasets as ds
import matplotlib.pyplot as plt

# %%
x,y = ds.load_flower_dataset( petals=4, noise=0.2)
print(x.shape, y.shape)
plt.scatter(x[0, :], x[1, :], c=y, s=40, cmap=plt.cm.Spectral)
# Out:
# (2, 500) (1, 500)

# %%
x,y = ds.load_spiral_dataset(N=1000, noise=0.2, K=5)
print(x.shape, y.shape)
plt.scatter(x[0, :], x[1, :], c=y, s=40, cmap=plt.cm.Spectral)
# Out:
# (2, 1000) (1, 1000)

# %%
x,y = ds.load_circles_dataset(n_samples=500, noise=0.1, factor=0.5)
print(x.shape, y.shape)
plt.scatter(x[0, :], x[1, :], c=y, s=40, cmap=plt.cm.Spectral)
# Out:
# (2, 500) (1, 500)

# %%
x,y = ds.load_moons_dataset(n_samples=500, noise=0.15)
print(x.shape, y.shape)
plt.scatter(x[0, :], x[1, :], c=y, s=40, cmap=plt.cm.Spectral)
# Out:
# (2, 500) (1, 500)

# %%
x,y = ds.load_blobs_dataset(n_samples=500, n_features=2, centers=4, cluster_std=1.0)
print(x.shape, y.shape)
plt.scatter(x[0, :], x[1, :], c=y, s=40, cmap=plt.cm.Spectral)
# Out:
# (2, 500) (1, 500)

# %%
x,y = ds.load_gaussian_quantiles_dataset(n_samples=500, n_features=2, n_classes=3, cov=0.25)
print(x.shape, y.shape)
plt.scatter(x[0, :], x[1, :], c=y, s=40, cmap=plt.cm.Spectral)
# Out:
# (2, 500) (1, 500)

# %%
x,y = ds.load_no_structure_dataset(N=500)
print(x.shape, y.shape)
plt.scatter(x[0, :], x[1, :], c=y, s=40, cmap=plt.cm.Spectral)
# Out:
# (2, 500) (1, 500)

# %%
x,y = ds.load_two_spirals_dataset(n_points=500, noise=0.5, rev=2.0)
print(x.shape, y.shape)
plt.scatter(x[0, :], x[1, :], c=y, s=40, cmap=plt.cm.Spectral)
# Out:
# (2, 1000) (1000,)
